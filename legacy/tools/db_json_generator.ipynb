# %% [markdown]
# # 1. Ojha
#
# 数据集其实real都是同一组，我是事先将其重组好
#
# Real 同一组

# %%
import os
import json
import re
from tqdm import tqdm

root='./'
Ojha_dict = {}
for subtask in os.listdir(os.path.join(root, 'Ojha')):
    temp_dict={}
    for img_path in os.listdir(os.path.join(root, 'Ojha', subtask, '0_real')):
        if os.path.isfile(os.path.join(root, 'Ojha', subtask, '0_real', img_path)):
            temp_dict[os.path.join(subtask, '0_real', img_path).replace(os.sep, '/')] = 0
    for img_path in os.listdir(os.path.join(root, 'Ojha', subtask, '1_fake')):
        if os.path.isfile(os.path.join(root, 'Ojha', subtask, '1_fake', img_path)):
            temp_dict[os.path.join(subtask, '1_fake', img_path).replace(os.sep, '/')] = 1
    Ojha_dict[subtask] = temp_dict


with open(os.path.join(root, 'Ojha', 'test.json'), 'w') as json_file:
    json.dump(Ojha_dict, json_file, indent=4)

# %% [markdown]
# # 2. UADFV

# %%
UADFV_dict = {}
temp_dict={}
for sub_folder in os.listdir(os.path.join(root, 'UADFV', 'fake', 'frames')):
    for img_path in os.listdir(os.path.join(root, 'UADFV', 'fake', 'frames', sub_folder)):
        if os.path.isfile(os.path.join(root, 'UADFV', 'fake', 'frames', sub_folder, img_path)):
            temp_dict[os.path.join('fake', 'frames', sub_folder, img_path).replace(os.sep, '/')] = 1

for sub_folder in os.listdir(os.path.join(root, 'UADFV', 'real', 'frames')):
    for img_path in os.listdir(os.path.join(root, 'UADFV', 'real', 'frames', sub_folder)):
        if os.path.isfile(os.path.join(root, 'UADFV', 'real', 'frames', sub_folder, img_path)):
            temp_dict[os.path.join('real', 'frames', sub_folder, img_path).replace(os.sep, '/')] = 0

UADFV_dict['all'] = temp_dict


with open(os.path.join(root, 'UADFV', 'test.json'), 'w') as json_file:
    json.dump(UADFV_dict, json_file, indent=4)

# %% [markdown]
# # 3. DiffusionForensics
#
# Real 同一组
# 这个数据集比较复杂，因为有三大类real，然后每个real都有很多fake

# %%
import os
import json
import re
from tqdm import tqdm

root='./'

DiffusionForensics_dict = {}
temp_dict={}

for ii in os.listdir(os.path.join(root, 'DiffusionForensics', 'imagenet', 'real')):
    for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'imagenet', 'real', ii)):
        temp_dict[os.path.join('imagenet', 'real', ii, img_path).replace(os.sep, '/')] = 0


for ii in os.listdir(os.path.join(root, 'DiffusionForensics', 'imagenet', 'sdv1')):
    for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'imagenet', 'sdv1', ii)):
        temp_dict[os.path.join('imagenet', 'sdv1', ii, img_path).replace(os.sep, '/')] = 1


DiffusionForensics_dict['imagenet_sdv1'] = temp_dict

temp_dict={}

for ii in os.listdir(os.path.join(root, 'DiffusionForensics', 'imagenet', 'real')):
    for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'imagenet', 'real', ii)):
        temp_dict[os.path.join('imagenet', 'real', ii, img_path).replace(os.sep, '/')] = 0


for ii in os.listdir(os.path.join(root, 'DiffusionForensics', 'imagenet', 'sdv1')):
    for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'imagenet', 'adm', ii)):
        temp_dict[os.path.join('imagenet', 'adm', ii, img_path).replace(os.sep, '/')] = 1


DiffusionForensics_dict['imagenet_adm'] = temp_dict

 ############################################################################################


temp_dict={}

for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'real')):
    temp_dict[os.path.join('lsun_bedroom', 'real', img_path).replace(os.sep, '/')] = 0


for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'sdv1_new1')):
    temp_dict[os.path.join('lsun_bedroom', 'sdv1_new1', img_path).replace(os.sep, '/')] = 1


DiffusionForensics_dict['lsun_bedroom_sdv1_new1'] = temp_dict

temp_dict={}

for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'real')):
    temp_dict[os.path.join('lsun_bedroom', 'real', img_path).replace(os.sep, '/')] = 0


for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'sdv1_new2')):
    temp_dict[os.path.join('lsun_bedroom', 'sdv1_new2', img_path).replace(os.sep, '/')] = 1


DiffusionForensics_dict['lsun_bedroom_sdv1_new2'] = temp_dict

temp_dict={}


for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'real')):
    temp_dict[os.path.join('lsun_bedroom', 'real', img_path).replace(os.sep, '/')] = 0


for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'adm')):
    temp_dict[os.path.join('lsun_bedroom', 'adm', img_path).replace(os.sep, '/')] = 1


DiffusionForensics_dict['lsun_bedroom_adm'] = temp_dict

temp_dict={}

for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'real')):
    temp_dict[os.path.join('lsun_bedroom', 'real', img_path).replace(os.sep, '/')] = 0


for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'iddpm')):
    temp_dict[os.path.join('lsun_bedroom', 'iddpm', img_path).replace(os.sep, '/')] = 1


DiffusionForensics_dict['lsun_bedroom_iddpm'] = temp_dict

temp_dict={}


for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'real')):
    temp_dict[os.path.join('lsun_bedroom', 'real', img_path).replace(os.sep, '/')] = 0


for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'ddpm')):
    temp_dict[os.path.join('lsun_bedroom', 'ddpm', img_path).replace(os.sep, '/')] = 1


DiffusionForensics_dict['lsun_bedroom_ddpm'] = temp_dict

temp_dict={}

for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'real')):
    temp_dict[os.path.join('lsun_bedroom', 'real', img_path).replace(os.sep, '/')] = 0


for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'pndm')):
    temp_dict[os.path.join('lsun_bedroom', 'pndm', img_path).replace(os.sep, '/')] = 1


DiffusionForensics_dict['lsun_bedroom_pndm'] = temp_dict
    
temp_dict={}

for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'real')):
    temp_dict[os.path.join('lsun_bedroom', 'real', img_path).replace(os.sep, '/')] = 0


for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'sdv2')):
    temp_dict[os.path.join('lsun_bedroom', 'sdv2', img_path).replace(os.sep, '/')] = 1


DiffusionForensics_dict['lsun_bedroom_sdv2'] = temp_dict

temp_dict={}

for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'real')):
    temp_dict[os.path.join('lsun_bedroom', 'real', img_path).replace(os.sep, '/')] = 0


for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'ldm')):
    temp_dict[os.path.join('lsun_bedroom', 'ldm', img_path).replace(os.sep, '/')] = 1


DiffusionForensics_dict['lsun_bedroom_ldm'] = temp_dict

temp_dict={}

for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'real')):
    temp_dict[os.path.join('lsun_bedroom', 'real', img_path).replace(os.sep, '/')] = 0


for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'vqdiffusion')):
    temp_dict[os.path.join('lsun_bedroom', 'vqdiffusion', img_path).replace(os.sep, '/')] = 1


DiffusionForensics_dict['lsun_bedroom_vqdiffusion'] = temp_dict


temp_dict={}

for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'real')):
    temp_dict[os.path.join('lsun_bedroom', 'real', img_path).replace(os.sep, '/')] = 0


for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'if')):
    temp_dict[os.path.join('lsun_bedroom', 'if', img_path).replace(os.sep, '/')] = 1


DiffusionForensics_dict['lsun_bedroom_if'] = temp_dict

temp_dict={}

for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'real')):
    temp_dict[os.path.join('lsun_bedroom', 'real', img_path).replace(os.sep, '/')] = 0


for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'dalle2')):
    temp_dict[os.path.join('lsun_bedroom', 'dalle2', img_path).replace(os.sep, '/')] = 1


DiffusionForensics_dict['lsun_bedroom_dalle2'] = temp_dict

temp_dict={}

for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'real')):
    temp_dict[os.path.join('lsun_bedroom', 'real', img_path).replace(os.sep, '/')] = 0


for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'lsun_bedroom', 'midjourney')):
    temp_dict[os.path.join('lsun_bedroom', 'midjourney', img_path).replace(os.sep, '/')] = 1


DiffusionForensics_dict['lsun_bedroom_midjourney'] = temp_dict


############################################################################################


temp_dict={}

for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'celebahq', 'real')):
    temp_dict[os.path.join('celebahq', 'real', img_path).replace(os.sep, '/')] = 0


for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'celebahq', 'sdv2')):
    temp_dict[os.path.join('celebahq', 'sdv2', img_path).replace(os.sep, '/')] = 1


DiffusionForensics_dict['celebahq_sdv2'] = temp_dict

temp_dict={}


for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'celebahq', 'real')):
    temp_dict[os.path.join('celebahq', 'real', img_path).replace(os.sep, '/')] = 0


for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'celebahq', 'if')):
    temp_dict[os.path.join('celebahq', 'if', img_path).replace(os.sep, '/')] = 1


DiffusionForensics_dict['celebahq_if'] = temp_dict

temp_dict={}

for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'celebahq', 'real')):
    temp_dict[os.path.join('celebahq', 'real', img_path).replace(os.sep, '/')] = 0


for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'celebahq', 'dalle2')):
    temp_dict[os.path.join('celebahq', 'dalle2', img_path).replace(os.sep, '/')] = 1


DiffusionForensics_dict['celebahq_dalle2'] = temp_dict

temp_dict={}

for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'celebahq', 'real')):
    temp_dict[os.path.join('celebahq', 'real', img_path).replace(os.sep, '/')] = 0


for img_path in os.listdir(os.path.join(root, 'DiffusionForensics', 'celebahq', 'midjourney')):
    temp_dict[os.path.join('celebahq', 'midjourney', img_path).replace(os.sep, '/')] = 1


DiffusionForensics_dict['celebahq_midjourney'] = temp_dict




with open(os.path.join(root, 'DiffusionForensics', 'test.json'), 'w') as json_file:
    json.dump(DiffusionForensics_dict, json_file, indent=4)

# %% [markdown]
# # 4. ForenSynths

# %%
import os
import json

root='./'
ForenSynths_dict = {}
for subtask in os.listdir(os.path.join(root, 'ForenSynths', 'test')):
    temp_dict={}
    if '0_real' in list(os.listdir(os.path.join(root, 'ForenSynths', 'test', subtask))):
        for img_path in os.listdir(os.path.join(root, 'ForenSynths', 'test', subtask, '0_real')):
            temp_dict[os.path.join('test', subtask, '0_real', img_path).replace(os.sep, '/')] = 0
        for img_path in os.listdir(os.path.join(root, 'ForenSynths', 'test', subtask, '1_fake')):
            temp_dict[os.path.join('test', subtask, '1_fake', img_path).replace(os.sep, '/')] = 1
    else:
        for ii in os.listdir(os.path.join(root, 'ForenSynths', 'test', subtask)):
            for img_path in os.listdir(os.path.join(root, 'ForenSynths', 'test', subtask, ii, '0_real')):
                temp_dict[os.path.join('test', subtask, ii, '0_real', img_path).replace(os.sep, '/')] = 0
            for img_path in os.listdir(os.path.join(root, 'ForenSynths', 'test', subtask, ii, '1_fake')):
                temp_dict[os.path.join('test', subtask, ii, '1_fake', img_path).replace(os.sep, '/')] = 1
    ForenSynths_dict[subtask] = temp_dict


with open(os.path.join(root, 'ForenSynths', 'test.json'), 'w') as json_file:
    json.dump(ForenSynths_dict, json_file, indent=4)

# %%
import os
import json

root='./'
ForenSynths_dict = {}
for subtask in os.listdir(os.path.join(root, 'ForenSynths', 'train')):
    temp_dict={}
    for ii in os.listdir(os.path.join(root, 'ForenSynths', 'train', subtask)):
        for img_path in os.listdir(os.path.join(root, 'ForenSynths', 'train', subtask, '0_real')):
            temp_dict[os.path.join('train', subtask, '0_real', img_path).replace(os.sep, '/')] = 0
        for img_path in os.listdir(os.path.join(root, 'ForenSynths', 'train', subtask, '1_fake')):
            temp_dict[os.path.join('train', subtask, '1_fake', img_path).replace(os.sep, '/')] = 1
    ForenSynths_dict[subtask] = temp_dict


with open(os.path.join(root, 'ForenSynths', 'train_binary.json'), 'w') as json_file:
    json.dump(ForenSynths_dict, json_file, indent=4)

# %%
import os
import json

root='./'
ForenSynths_dict = {}
for subtask in os.listdir(os.path.join(root, 'ForenSynths', 'val')):
    temp_dict={}
    for ii in os.listdir(os.path.join(root, 'ForenSynths', 'val', subtask)):
        for img_path in os.listdir(os.path.join(root, 'ForenSynths', 'val', subtask, '0_real')):
            temp_dict[os.path.join('val', subtask, '0_real', img_path).replace(os.sep, '/')] = 0
        for img_path in os.listdir(os.path.join(root, 'ForenSynths', 'val', subtask, '1_fake')):
            temp_dict[os.path.join('val', subtask, '1_fake', img_path).replace(os.sep, '/')] = 1
    ForenSynths_dict[subtask] = temp_dict


with open(os.path.join(root, 'ForenSynths', 'val.json'), 'w') as json_file:
    json.dump(ForenSynths_dict, json_file, indent=4)

# %% [markdown]
# # 5. AntifakePrompt

# %%
def find_images(root, sub):
    image_pattern = re.compile(r'.*\.(jpg|jpeg|png|bmp)$', re.IGNORECASE)
    image_paths = []
    for current_root, dirs, files in os.walk(os.path.join(root, sub)):
        for file in files:
            if image_pattern.match(file):
                full_path = os.path.join(current_root, file)
                if os.path.isfile(full_path):
                    relative_path = os.path.relpath(full_path, root)
                    image_paths.append(relative_path.replace(os.sep, '/'))
    return image_paths

data_path = os.path.join(root, 'AntifakePrompt')

AntifakePrompt_dict = {}

real = find_images(data_path, 'COCO')
print(len(real))
temp_dict={}
for img_path in real:
    temp_dict[img_path] = 0


AntifakePrompt_dict['COCO'] = temp_dict

real = find_images(data_path, 'flickr30k_224')
print(len(real))
temp_dict={}
for img_path in real:
    temp_dict[img_path] = 0


AntifakePrompt_dict['Flickr'] = temp_dict

fake = find_images(data_path, 'AdvAtk_Imagenet')
print(len(fake))
temp_dict={}
for img_path in fake:
    temp_dict[img_path] = 1


AntifakePrompt_dict['AdvAtk'] = temp_dict

fake = find_images(data_path, os.path.join('DALLE2', 'commonFake_COCO')) + find_images(data_path, os.path.join('DALLE2', 'commonFake_Flickr'))
print(len(fake))
temp_dict={}
for img_path in fake:
    temp_dict[img_path] = 1


AntifakePrompt_dict['DALLE2'] = temp_dict

fake = find_images(data_path, 'deeperforensics_faceOnly')
print(len(fake))
temp_dict={}
for img_path in fake:
    temp_dict[img_path] = 1


AntifakePrompt_dict['Deeperforensics'] = temp_dict

fake = find_images(data_path, os.path.join('IF', 'commonFake_COCO')) + find_images(data_path, os.path.join('IF', 'commonFake_Flickr'))
print(len(fake))
temp_dict={}
for img_path in fake:
    temp_dict[img_path] = 1


AntifakePrompt_dict['IF'] = temp_dict

fake = find_images(data_path, 'lte_SR4_224')
print(len(fake))
temp_dict={}
for img_path in fake:
    temp_dict[img_path] = 1


AntifakePrompt_dict['lte'] = temp_dict

fake = find_images(data_path, 'SD2Inpaint_224')
print(len(fake))
temp_dict={}
for img_path in fake:
    temp_dict[img_path] = 1


AntifakePrompt_dict['SD2Inpaint'] = temp_dict

fake = find_images(data_path, os.path.join('SDXL', 'commonFake_COCO')) + find_images(data_path, os.path.join('SDXL', 'commonFake_Flickr'))
print(len(fake))
temp_dict={}
for img_path in fake:
    temp_dict[img_path] = 1


AntifakePrompt_dict['SDXL'] = temp_dict

fake = find_images(data_path, 'Backdoor_Imagenet')
print(len(fake))
temp_dict={}
for img_path in fake:
    temp_dict[img_path] = 1


AntifakePrompt_dict['Backdoor'] = temp_dict

fake = find_images(data_path, 'Control_COCO')
print(len(fake))
temp_dict={}
for img_path in fake:
    temp_dict[img_path] = 1


AntifakePrompt_dict['Control'] = temp_dict

fake = find_images(data_path, 'DataPoison_Imagenet')
print(len(fake))
temp_dict={}
for img_path in fake:
    temp_dict[img_path] = 1


AntifakePrompt_dict['DataPoison'] = temp_dict

fake = find_images(data_path, 'lama_224')
print(len(fake))
temp_dict={}
for img_path in fake:
    temp_dict[img_path] = 1


AntifakePrompt_dict['Lama'] = temp_dict

fake = find_images(data_path, os.path.join('SD2', 'commonFake_COCO')) + find_images(data_path, os.path.join('SD2', 'commonFake_Flickr'))
print(len(fake))
temp_dict={}
for img_path in fake:
    temp_dict[img_path] = 1


AntifakePrompt_dict['SD2'] = temp_dict

fake = find_images(data_path, 'SD2SuperRes_SR4_224')
print(len(fake))
temp_dict={}
for img_path in fake:
    temp_dict[img_path] = 1


AntifakePrompt_dict['SD2SuperRes'] = temp_dict

fake = find_images(data_path, 'SGXL')
print(len(fake))
temp_dict={}
for img_path in fake:
    temp_dict[img_path] = 1


AntifakePrompt_dict['SGXL'] = temp_dict


with open(os.path.join(root, 'AntifakePrompt', 'test.json'), 'w') as json_file:
    json.dump(AntifakePrompt_dict, json_file, indent=4)
# Out:
# 3000
# 3000
# 3000
# 3000
# 3000
# 3000
# 3000
# 3000
# 3000
# 3000
# 3000
# 3000
# 3000
# 3000
# 3000
# 3000

# %% [markdown]
# # 6. CelebDF v1
#
# List_of_testing_videos.txt 的label和别人是反着的

# %%
import os
import json
import re
from tqdm import tqdm

CelebDFV1_dict = {}
temp_dict={}

with open(os.path.join(root, 'Celeb-DF-v1', 'List_of_testing_videos.txt'), 'r') as f:
    lines = f.readlines()

for line in tqdm(lines):
    label, id = line.split()
    dir_name, file_name = os.path.split(id)
    base_name, _ = os.path.splitext(file_name)
    for frame_id in os.listdir(os.path.join(root, 'Celeb-DF-v1', dir_name, 'frames')):
        for img_path in os.listdir(os.path.join(root, 'Celeb-DF-v1', dir_name, 'frames', frame_id)):
            if os.path.isfile(os.path.join(root, 'Celeb-DF-v1', dir_name, 'frames', frame_id, img_path)):
                if label == "1":
                    temp_dict[os.path.join(dir_name, 'frames', frame_id, img_path).replace(os.sep, '/')] = 0
                else:
                    temp_dict[os.path.join(dir_name, 'frames', frame_id, img_path).replace(os.sep, '/')] = 1

CelebDFV1_dict['all'] = temp_dict

with open(os.path.join(root, 'Celeb-DF-v1', 'test.json'), 'w') as json_file:
    json.dump(CelebDFV1_dict, json_file, indent=4)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [03:11<00:00,  1.91s/it]

# %% [markdown]
# # 7. CelebDF v2

# %%
import os
import json
import re
from tqdm import tqdm

CelebDFV2_dict = {}
temp_dict={}

with open(os.path.join(root, 'Celeb-DF-v2', 'List_of_testing_videos.txt'), 'r') as f:
    lines = f.readlines()

for line in tqdm(lines):
    label, id = line.split()
    dir_name, file_name = os.path.split(id)
    base_name, _ = os.path.splitext(file_name)
    for frame_id in os.listdir(os.path.join(root, 'Celeb-DF-v2', dir_name, 'frames')):
        for img_path in os.listdir(os.path.join(root, 'Celeb-DF-v2', dir_name, 'frames', frame_id)):
            if os.path.isfile(os.path.join(root, 'Celeb-DF-v2', dir_name, 'frames', frame_id, img_path)):
                if label == "1":
                    temp_dict[os.path.join(dir_name, 'frames', frame_id, img_path).replace(os.sep, '/')] = 0
                else:
                    temp_dict[os.path.join(dir_name, 'frames', frame_id, img_path).replace(os.sep, '/')] = 1

CelebDFV2_dict['all'] = temp_dict

with open(os.path.join(root, 'Celeb-DF-v2', 'test.json'), 'w') as json_file:
    json.dump(CelebDFV2_dict, json_file, indent=4)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [03:09<00:00,  1.90s/it]

# %% [markdown]
# # 8. FF++

# %% [markdown]
# # 9. AIGCDetect
#
# https://github.com/Ekko-zn/AIGCDetectBenchmark

# %%
import os
import json

root='./'
ForenSynths_dict = {}
for subtask in os.listdir(os.path.join(root, 'AIGCDetect')):
    temp_dict={}
    if '0_real' in list(os.listdir(os.path.join(root, 'AIGCDetect', subtask))):
        for img_path in os.listdir(os.path.join(root, 'AIGCDetect',  subtask, '0_real')):
            temp_dict[os.path.join(subtask, '0_real', img_path).replace(os.sep, '/')] = 0
        for img_path in os.listdir(os.path.join(root, 'AIGCDetect', subtask, '1_fake')):
            temp_dict[os.path.join(subtask, '1_fake', img_path).replace(os.sep, '/')] = 1
    else:
        for ii in os.listdir(os.path.join(root, 'AIGCDetect', subtask)):
            for img_path in os.listdir(os.path.join(root, 'AIGCDetect', subtask, ii, '0_real')):
                temp_dict[os.path.join(subtask, ii, '0_real', img_path).replace(os.sep, '/')] = 0
            for img_path in os.listdir(os.path.join(root, 'AIGCDetect', subtask, ii, '1_fake')):
                temp_dict[os.path.join(subtask, ii, '1_fake', img_path).replace(os.sep, '/')] = 1
    ForenSynths_dict[subtask] = temp_dict
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 8
#       6 root='./'
#       7 ForenSynths_dict = {}
# ----> 8 for subtask in os.listdir(os.path.join(root, 'AIGCDetect', 'test')):
#       9     temp_dict={}
#      10     if '0_real' in list(os.listdir(os.path.join(root, 'AIGCDetect', subtask))):
#
# FileNotFoundError: [WinError 3] 系统找不到指定的路径。: './AIGCDetect\\test'

# %%
with open(os.path.join(root, 'AIGCDetect', 'test.json'), 'w') as json_file:
    json.dump(ForenSynths_dict, json_file, indent=4)

# %% [markdown]
# # 9. DFDC

# %% [markdown]
# # 10. DFDCP

# %% [markdown]
# # 11. Diffusion1kStep

# %%
import os
import json
import re
from tqdm import tqdm

root='./'
ForenSynths_dict = {}
for subtask in os.listdir(os.path.join(root, 'Diffusion1kStep')):
    temp_dict={}
    if '0_real' in list(os.listdir(os.path.join(root, 'Diffusion1kStep', subtask))):
        for img_path in os.listdir(os.path.join(root, 'Diffusion1kStep',  subtask, '0_real')):
            temp_dict[os.path.join(subtask, '0_real', img_path).replace(os.sep, '/')] = 0
        for img_path in os.listdir(os.path.join(root, 'Diffusion1kStep', subtask, '1_fake')):
            temp_dict[os.path.join(subtask, '1_fake', img_path).replace(os.sep, '/')] = 1
    else:
        for ii in os.listdir(os.path.join(root, 'Diffusion1kStep', subtask)):
            for img_path in os.listdir(os.path.join(root, 'Diffusion1kStep', subtask, ii, '0_real')):
                temp_dict[os.path.join(subtask, ii, '0_real', img_path).replace(os.sep, '/')] = 0
            for img_path in os.listdir(os.path.join(root, 'Diffusion1kStep', subtask, ii, '1_fake')):
                temp_dict[os.path.join(subtask, ii, '1_fake', img_path).replace(os.sep, '/')] = 1
    ForenSynths_dict[subtask] = temp_dict
    


with open(os.path.join(root, 'Diffusion1kStep', 'test.json'), 'w') as json_file:
    json.dump(ForenSynths_dict, json_file, indent=4)

# %% [markdown]
# # 12. GANGen-Detection

# %%
import os
import json
import re
from tqdm import tqdm

root='./'
ForenSynths_dict = {}
for subtask in os.listdir(os.path.join(root, 'GANGen-Detection')):
    temp_dict={}
    if '0_real' in list(os.listdir(os.path.join(root, 'GANGen-Detection', subtask))):
        for img_path in os.listdir(os.path.join(root, 'GANGen-Detection',  subtask, '0_real')):
            temp_dict[os.path.join(subtask, '0_real', img_path).replace(os.sep, '/')] = 0
        for img_path in os.listdir(os.path.join(root, 'GANGen-Detection', subtask, '1_fake')):
            temp_dict[os.path.join(subtask, '1_fake', img_path).replace(os.sep, '/')] = 1
    else:
        for ii in os.listdir(os.path.join(root, 'GANGen-Detection', subtask)):
            for img_path in os.listdir(os.path.join(root, 'GANGen-Detection', subtask, ii, '0_real')):
                temp_dict[os.path.join(subtask, ii, '0_real', img_path).replace(os.sep, '/')] = 0
            for img_path in os.listdir(os.path.join(root, 'GANGen-Detection', subtask, ii, '1_fake')):
                temp_dict[os.path.join(subtask, ii, '1_fake', img_path).replace(os.sep, '/')] = 1
    ForenSynths_dict[subtask] = temp_dict
    


with open(os.path.join(root, 'GANGen-Detection', 'test.json'), 'w') as json_file:
    json.dump(ForenSynths_dict, json_file, indent=4)

# %% [markdown]
# # 13. AI_recognition_dataset

# %%
import os
import json
import re
from tqdm import tqdm

root='./'
data_dict = {}

temp_dict={}
for img_path in os.listdir(os.path.join(root, 'AI_recognition_dataset', 'real')):
    temp_dict[os.path.join('real', img_path).replace(os.sep, '/')] = 0

for img_path in os.listdir(os.path.join(root, 'AI_recognition_dataset', 'fake')):
    temp_dict[os.path.join('fake', img_path).replace(os.sep, '/')] = 1

data_dict['all'] = temp_dict


with open(os.path.join(root, 'AI_recognition_dataset', 'test.json'), 'w') as json_file:
    json.dump(data_dict, json_file, indent=4)

# %% [markdown]
# # 14. Artifact

# %%
import csv
import os
import json

real_names = ["afhq", "coco", "celebahq", "ffhq", "imagenet", "landscape", "lsun", "metfaces"]

root='./'
data_dict = {}

for subset in real_names:
    temp_dict={}
    with open(os.path.join(root, subset, 'metadata.csv'), newline='', encoding='utf-8') as file:
        reader = csv.reader(file)
        _ = next(reader)
        for row in reader:
            if int(row[2]) == 0:
                temp_dict[os.path.join(subset, row[1])] = 0
            else:
                print(row)
    data_dict[subset] = temp_dict


temp_dict={}
with open(os.path.join(root, 'cycle_gan', 'metadata.csv'), newline='', encoding='utf-8') as file:
    reader = csv.reader(file)
    _ = next(reader)
    for row in reader:
        if int(row[2]) == 0:
            temp_dict[os.path.join('cycle_gan', row[1])] = 0
        else:
            print(row)

data_dict['real_cyclegan'] = temp_dict


fake_names = [
    "diffusion_gan", "gau_gan", "lama", "mat", "projected_gan", "stylegan1", 
    "vq_diffusion", "big_gan", "face_synthetics", "generative_inpainting", 
    "sfhq", "stylegan2", "ddpm", "glide", "latent_diffusion", "palette", 
    "stable_diffusion", "stylegan3", "cips", "denoising_diffusion_gan", 
    "gansformer", "pro_gan", "star_gan", "taming_transformer"
]

for subset in fake_names:
    temp_dict={}
    with open(os.path.join(root, subset, 'metadata.csv'), newline='', encoding='utf-8') as file:
        reader = csv.reader(file)
        _ = next(reader)
        for row in reader:
            if int(row[2]) in [1,2,3,4,5,6]:
                temp_dict[os.path.join(subset, row[1])] = 1
            elif int(row[2]) == 0:
                temp_dict[os.path.join(subset, row[1])] = 0
            else:
                print(row)
    data_dict[subset] = temp_dict

temp_dict={}
with open(os.path.join(root, 'cycle_gan', 'metadata.csv'), newline='', encoding='utf-8') as file:
    reader = csv.reader(file)
    _ = next(reader)
    for row in reader:
        if int(row[2]) == 6:
            temp_dict[os.path.join('cycle_gan', row[1])] = 1
        else:
            print(row)

data_dict['cyclegan'] = temp_dict


with open(os.path.join(root, 'test.json'), 'w') as json_file:
    json.dump(data_dict, json_file, indent=4)

# %% [markdown]
# # 15. DIF

# %%
import os
import json
import re
from tqdm import tqdm

root='./'
data_dict = {}
for subtask in os.listdir(os.path.join(root, 'DIF_testset')):
    temp_dict={}
    for img_path in os.listdir(os.path.join(root, 'DIF_testset',  subtask, '0_real')):
        temp_dict[os.path.join(subtask, '0_real', img_path).replace(os.sep, '/')] = 0
    for img_path in os.listdir(os.path.join(root, 'DIF_testset', subtask, '1_fake')):
        temp_dict[os.path.join(subtask, '1_fake', img_path).replace(os.sep, '/')] = 1
    data_dict[subtask] = temp_dict



with open(os.path.join(root, 'DIF_testset', 'test.json'), 'w') as json_file:
    json.dump(data_dict, json_file, indent=4)

# %% [markdown]
# # Fake2M

# %%
import pathlib
import os
import json
import re
from tqdm import tqdm


def find_images(directory_path):
    base_path = pathlib.Path(directory_path).resolve()  
    path = pathlib.Path(directory_path)
    path = path.resolve()
    image_extensions = {".jpg", ".jpeg", ".png", ".webp"}
    images = [str(file.relative_to(base_path)) for file in path.rglob('*') if file.suffix.lower() in image_extensions]
    return images

root='./'
data_dict = {}
for subtask in os.listdir(os.path.join(root, 'Fake2M')):
    temp_dict={}
    images = find_images(os.path.join(root, 'Fake2M', subtask))
    for img_path in images:
        temp_dict[os.path.join(subtask, img_path).replace(os.sep, '/')] = 1
    data_dict[subtask] = temp_dict



with open(os.path.join(root, 'Fake2M', 'test.json'), 'w') as json_file:
    json.dump(data_dict, json_file, indent=4)

# %% [markdown]
# # synthbuster

# %%
import csv
import os
import json
import shutil

names = ['dalle2','firefly','stable-diffusion-1-4','stable-diffusion-xl', 'dalle3','glide','midjourney-v5','stable-diffusion-1-3','stable-diffusion-2', ]

root='./'
data_dict = {}
image_extensions = {"jpg", "jpeg", "png", "webp"}
for subtask in names:
    temp_dict={}
    for img_path in os.listdir(os.path.join(root, 'synthbuster',  subtask)):
        print(img_path)
        if img_path.split('.')[-1].lower() in image_extensions:
            temp_dict[os.path.join(subtask, img_path).replace(os.sep, '/')] = 1
    for img_path in os.listdir(os.path.join(root, 'synthbuster', 'real_RAISE_1k')):
        if img_path.split('.')[-1].lower() in image_extensions:
            temp_dict[os.path.join('real_RAISE_1k', img_path).replace(os.sep, '/')] = 0
    data_dict[subtask] = temp_dict


with open(os.path.join(root, 'synthbuster', 'test.json'), 'w') as json_file:
    json.dump(data_dict, json_file, indent=4)

# %% [markdown]
# # AIArt

# %%
import os
import json
import re
from tqdm import tqdm

root='./'
data_dict = {}
for subtask in os.listdir(os.path.join(root, 'AIArt')):
    temp_dict={}
    for img_path in os.listdir(os.path.join(root, 'AIArt',  subtask, '0_real')):
        temp_dict[os.path.join(subtask, '0_real', img_path).replace(os.sep, '/')] = 0
    for img_path in os.listdir(os.path.join(root, 'AIArt', subtask, '1_fake')):
        temp_dict[os.path.join(subtask, '1_fake', img_path).replace(os.sep, '/')] = 1
    data_dict[subtask] = temp_dict


with open(os.path.join(root, 'AIArt', 'test.json'), 'w') as json_file:
    json.dump(data_dict, json_file, indent=4)

# %% [markdown]
# # Our

# %%
import os
import json
import re

root='./'
data_dict = {}

temp_dict={}
for img_path in os.listdir(os.path.join(root, 'our', 'coco2017/images/train2017')):
    temp_dict[os.path.join('coco2017/images/train2017', img_path).replace(os.sep, '/')] = 0

for img_path in os.listdir(os.path.join(root, 'our', 'coco2017/images/val2017')):
    temp_dict[os.path.join('coco2017/images/val2017', img_path).replace(os.sep, '/')] = 0

for img_path in os.listdir(os.path.join(root, 'our', 'sd15')):
    temp_dict[os.path.join('sd15', img_path).replace(os.sep, '/')] = 1

data_dict['all'] = temp_dict

with open(os.path.join(root, 'our', 'train.json'), 'w') as json_file:
    json.dump(data_dict, json_file, indent=4)

# %% [markdown]
# # CLIPBased

# %%
import csv

file_path = r'C:\Users\yw26g23\OneDrive - University of Southampton\Desktop\commercial_tools.csv'

data_dict = {}

with open(file_path, mode='r', newline='') as file:
    csv_reader = csv.DictReader(file)
    for row in csv_reader:
        typ = row['typ']
        filename = row['filename']
        if typ not in data_dict:
            data_dict[typ] = [filename]
        else:
            data_dict[typ].append(filename)

# %%
import json
import re

root='./'
final_dict = {}

temp_dict={}
for value in data_dict['dalle2']:
    temp_dict[value] = 1
for value in data_dict['real']:
    temp_dict[value] = 0
final_dict['dalle2'] = temp_dict

temp_dict={}
for value in data_dict['dalle3']:
    temp_dict[value] = 1
for value in data_dict['real']:
    temp_dict[value] = 0
final_dict['dalle3'] = temp_dict

temp_dict={}
for value in data_dict['firefly']:
    temp_dict[value] = 1
for value in data_dict['real']:
    temp_dict[value] = 0
final_dict['firefly'] = temp_dict

temp_dict={}
for value in data_dict['midjourney-v5']:
    temp_dict[value] = 1
for value in data_dict['real']:
    temp_dict[value] = 0
final_dict['midjourney-v5'] = temp_dict


with open('test.json', 'w') as json_file:
    json.dump(final_dict, json_file, indent=4)

# %%
import os
import json

# 定义目录路径
base_directory = 'train'  # 当前目录
latent_prefix = 'latent_diffusion_'
real_directory = 'real'
output_json = 'train.json'

final_dict = {}
image_labels = {}

# 遍历当前目录下的所有文件夹
for root, dirs, files in os.walk(base_directory):
    for directory in dirs:
        dir_path = os.path.join(root, directory)
        if directory.startswith(latent_prefix):
            label = 1  # fake
        elif directory == real_directory:
            label = 0  # real
        else:
            continue
        for sub_root, _, sub_files in os.walk(dir_path):
            for file in sub_files:
                if file.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif', '.tiff')):
                    relative_path = os.path.relpath(os.path.join(base_directory, sub_root, file), base_directory)
                    image_labels[relative_path] = label


final_dict['all'] = image_labels

with open(output_json, 'w') as json_file:
    json.dump(final_dict, json_file, indent=4)

print(f'JSON file "{output_json}" has been created with image labels.')

# %% [markdown]
# # synthwildx

# %%
import json
import re
import os
root='./'
final_dict = {}

temp_dict={}
for value in os.listdir('dalle3'):
    temp_dict[os.path.join('dalle3', value)] = 1

for value in os.listdir('real'):
    temp_dict[os.path.join('real', value)] = 0

final_dict['dalle3'] = temp_dict

temp_dict={}
for value in os.listdir('firefly'):
    temp_dict[os.path.join('firefly', value)] = 1

for value in os.listdir('real'):
    temp_dict[os.path.join('real', value)] = 0

final_dict['firefly'] = temp_dict

temp_dict={}
for value in os.listdir('midjourney_v5'):
    temp_dict[os.path.join('midjourney_v5', value)] = 1

for value in os.listdir('real'):
    temp_dict[os.path.join('real', value)] = 0

final_dict['midjourney_v5'] = temp_dict

with open('test.json', 'w') as json_file:
    json.dump(final_dict, json_file, indent=4)

# %% [markdown]
# # GenImage

# %%
import json
import re
import os
root='./'
final_dict = {}

temp_dict={}
for value in os.listdir(os.path.join('ADM', 'train', 'ai')):
    temp_dict[os.path.join('ADM', 'train', 'ai', value)] = 1

for value in os.listdir(os.path.join('ADM', 'train', 'nature')):
    temp_dict[os.path.join('ADM', 'train', 'nature', value)] = 0

final_dict['ADM'] = temp_dict

temp_dict={}
for value in os.listdir(os.path.join('stable_diffusion_v_1_4', 'train', 'ai')):
    temp_dict[os.path.join('stable_diffusion_v_1_4', 'train', 'ai', value)] = 1

for value in os.listdir(os.path.join('stable_diffusion_v_1_4', 'train', 'nature')):
    temp_dict[os.path.join('stable_diffusion_v_1_4', 'train', 'nature', value)] = 0

final_dict['stable_diffusion_v_1_4'] = temp_dict

temp_dict={}
for value in os.listdir(os.path.join('stable_diffusion_v_1_5', 'train', 'ai')):
    temp_dict[os.path.join('stable_diffusion_v_1_5', 'train', 'ai', value)] = 1

for value in os.listdir(os.path.join('stable_diffusion_v_1_5', 'train', 'nature')):
    temp_dict[os.path.join('stable_diffusion_v_1_5', 'train', 'nature', value)] = 0

final_dict['stable_diffusion_v_1_5'] = temp_dict

temp_dict={}
for value in os.listdir(os.path.join('VQDM', 'train', 'ai')):
    temp_dict[os.path.join('VQDM', 'train', 'ai', value)] = 1

for value in os.listdir(os.path.join('VQDM', 'train', 'nature')):
    temp_dict[os.path.join('VQDM', 'train', 'nature', value)] = 0

final_dict['VQDM'] = temp_dict

temp_dict={}
for value in os.listdir(os.path.join('Midjourney', 'train', 'ai')):
    temp_dict[os.path.join('Midjourney', 'train', 'ai', value)] = 1

for value in os.listdir(os.path.join('Midjourney', 'train', 'nature')):
    temp_dict[os.path.join('Midjourney', 'train', 'nature', value)] = 0

final_dict['Midjourney'] = temp_dict

temp_dict={}
for value in os.listdir(os.path.join('wukong', 'train', 'ai')):
    temp_dict[os.path.join('wukong', 'train', 'ai', value)] = 1

for value in os.listdir(os.path.join('wukong', 'train', 'nature')):
    temp_dict[os.path.join('wukong', 'train', 'nature', value)] = 0

final_dict['wukong'] = temp_dict

temp_dict={}
for value in os.listdir(os.path.join('Glide', 'train', 'ai')):
    temp_dict[os.path.join('Glide', 'train', 'ai', value)] = 1

for value in os.listdir(os.path.join('Glide', 'train', 'nature')):
    temp_dict[os.path.join('Glide', 'train', 'nature', value)] = 0

final_dict['Glide'] = temp_dict



temp_dict={}
for value in os.listdir(os.path.join('BigGAN', 'val', 'ai')):
    temp_dict[os.path.join('BigGAN', 'val', 'ai', value)] = 1


for value in os.listdir(os.path.join('BigGAN', 'val', 'nature')):
    temp_dict[os.path.join('BigGAN', 'val', 'nature', value)] = 0


final_dict['BigGAN'] = temp_dict




with open('train.json', 'w') as json_file:
    json.dump(final_dict, json_file, indent=4)



import json
import re
import os
root='./'
final_dict = {}

temp_dict={}
for value in os.listdir(os.path.join('ADM', 'val', 'ai')):
    temp_dict[os.path.join('ADM', 'val', 'ai', value)] = 1


for value in os.listdir(os.path.join('ADM', 'val', 'nature')):
    temp_dict[os.path.join('ADM', 'val', 'nature', value)] = 0

final_dict['ADM'] = temp_dict

temp_dict={}
for value in os.listdir(os.path.join('Midjourney', 'val', 'ai')):
    temp_dict[os.path.join('Midjourney', 'val', 'ai', value)] = 1


for value in os.listdir(os.path.join('Midjourney', 'val', 'nature')):
    temp_dict[os.path.join('Midjourney', 'val', 'nature', value)] = 0

final_dict['Midjourney'] = temp_dict


temp_dict={}
for value in os.listdir(os.path.join('wukong', 'val', 'ai')):
    temp_dict[os.path.join('wukong', 'val', 'ai', value)] = 1


for value in os.listdir(os.path.join('wukong', 'val', 'nature')):
    temp_dict[os.path.join('wukong', 'val', 'nature', value)] = 0

final_dict['wukong'] = temp_dict

temp_dict={}
for value in os.listdir(os.path.join('Glide', 'val', 'ai')):
    temp_dict[os.path.join('Glide', 'val', 'ai', value)] = 1


for value in os.listdir(os.path.join('Glide', 'val', 'nature')):
    temp_dict[os.path.join('Glide', 'val', 'nature', value)] = 0

final_dict['Glide'] = temp_dict



temp_dict={}
for value in os.listdir(os.path.join('stable_diffusion_v_1_4', 'val', 'ai')):
    temp_dict[os.path.join('stable_diffusion_v_1_4', 'val', 'ai', value)] = 1


for value in os.listdir(os.path.join('stable_diffusion_v_1_4', 'val', 'nature')):
    temp_dict[os.path.join('stable_diffusion_v_1_4', 'val', 'nature', value)] = 0


final_dict['stable_diffusion_v_1_4'] = temp_dict

temp_dict={}
for value in os.listdir(os.path.join('stable_diffusion_v_1_5', 'val', 'ai')):
    temp_dict[os.path.join('stable_diffusion_v_1_5', 'val', 'ai', value)] = 1


for value in os.listdir(os.path.join('stable_diffusion_v_1_5', 'val', 'nature')):
    temp_dict[os.path.join('stable_diffusion_v_1_5', 'val', 'nature', value)] = 0


final_dict['stable_diffusion_v_1_5'] = temp_dict


temp_dict={}
for value in os.listdir(os.path.join('VQDM', 'val', 'ai')):
    temp_dict[os.path.join('VQDM', 'val', 'ai', value)] = 1


for value in os.listdir(os.path.join('VQDM', 'val', 'nature')):
    temp_dict[os.path.join('VQDM', 'val', 'nature', value)] = 0


final_dict['VQDM'] = temp_dict




temp_dict={}
for value in os.listdir(os.path.join('BigGAN', 'val', 'ai')):
    temp_dict[os.path.join('BigGAN', 'val', 'ai', value)] = 1


for value in os.listdir(os.path.join('BigGAN', 'val', 'nature')):
    temp_dict[os.path.join('BigGAN', 'val', 'nature', value)] = 0


final_dict['BigGAN'] = temp_dict



with open('test.json', 'w') as json_file:
    json.dump(final_dict, json_file, indent=4)

# %%
import json
import random
import imghdr
import os
import requests
from PIL import Image
from io import BytesIO
import mimetypes
from datasets import load_dataset
from tqdm import tqdm
import datasets

datasets.config.STREAMING_READ_MAX_RETRIES = 5000
datasets.config.STREAMING_READ_RETRY_INTERVAL = 10

elsa_data = load_dataset("elsaEU/ELSA_D3", split="train", streaming=True)

# 设置随机种子以确保结果可重复
random.seed(42)

# 定义每个模型要选择的样本数量
num_samples_per_model = 10000

# 创建一个字典来存储每个模型已选择的样本数量
selected_counts = {
    'model_gen0': 0,
    'model_gen1': 0,
    'model_gen2': 0,
    'model_gen3': 0
}
original_prompts = {}

# 创建一个集合来存储已经存在的 ID
existing_ids = set()

# 遍历所有模型的文件夹,将已经存在的 ID 添加到集合中
for model in ['model_gen0', 'model_gen1', 'model_gen2', 'model_gen3']:
    real_dir = f"{model}/0_real"
    fake_dir = f"{model}/1_fake"

    if os.path.exists(real_dir):
        for filename in os.listdir(real_dir):
            existing_ids.add(os.path.splitext(filename)[0])

    if os.path.exists(fake_dir):
        for filename in os.listdir(fake_dir):
            existing_ids.add(os.path.splitext(filename)[0])

# 遍历数据集并随机选择样本
for example in elsa_data:
    print(selected_counts)
    if all(count >= num_samples_per_model for count in selected_counts.values()):
        break

    if example['id'] in existing_ids:
        print(f"Skipping sample {example['id']} as it already exists.")
        original_prompts[example['id']] = example['original_prompt']
        continue

    model = random.choice(['model_gen0', 'model_gen1', 'model_gen2', 'model_gen3'])
    if selected_counts[model] < num_samples_per_model:
        if example[model] is not None:
            os.makedirs(f"{model}/0_real", exist_ok=True)
            os.makedirs(f"{model}/1_fake", exist_ok=True)

            try:
                response = requests.get(example['url'], timeout=1)
                response.raise_for_status()
                content_type = response.headers.get('Content-Type')

                image_type = imghdr.what(None, response.content)
                extension = ''
                if image_type:
                    extension = f".{image_type}"

                # 如果扩展名不是图像格式或无法确定格式,使用默认的扩展名 ".jpg"
                if extension not in ['.jpg', '.jpeg', '.png', '.webp']:
                    continue

                real_image = Image.open(BytesIO(response.content))
                real_image.save(f"{model}/0_real/{example['id']}{extension}")
                example[model.replace('model', 'image')].save(f"{model}/1_fake/{example['id']}.png")
                original_prompts[example['id']] = example['original_prompt']
                selected_counts[model] += 1
            except (requests.exceptions.RequestException, IOError):
                print(f"Skipping sample {example['id']} due to download failure.")

    with open("original_prompts.json", 'w') as f:
        json.dump(original_prompts, f, indent=2)

# %%
import json
import re
import os
root='./'
final_dict = {}

temp_dict={}
for value in os.listdir('model_gen0'):
    temp_dict[os.path.join('model_gen0', value)] = 1

for value in os.listdir('real'):
    temp_dict[os.path.join('real', value)] = 0

final_dict['model_gen0'] = temp_dict

with open('train.json', 'w') as json_file:
    json.dump(final_dict, json_file, indent=4)

# %% [markdown]
# # IEEESP24

# %%
import json
import os
final_dict = {}

temp_dict={}
for value in os.listdir(os.path.join('SD_dataset', 'test', 'fake')):
    temp_dict[os.path.join('SD_dataset', 'test', 'fake', value)] = 1

for value in os.listdir(os.path.join('SD_dataset', 'test', 'real')):
    temp_dict[os.path.join('SD_dataset', 'test', 'real', value)] = 0

final_dict['SD'] = temp_dict


temp_dict={}
for value in os.listdir(os.path.join('FM_genimages', 'AbsoluteReality')):
    temp_dict[os.path.join('FM_genimages', 'AbsoluteReality', value)] = 1

for value in os.listdir(os.path.join('SD_dataset', 'test', 'real')):
    temp_dict[os.path.join('SD_dataset', 'test', 'real', value)] = 0

final_dict['AbsoluteReality'] = temp_dict

temp_dict={}
for value in os.listdir(os.path.join('FM_genimages', 'AnalogDiffusion')):
    temp_dict[os.path.join('FM_genimages', 'AnalogDiffusion', value)] = 1

for value in os.listdir(os.path.join('SD_dataset', 'test', 'real')):
    temp_dict[os.path.join('SD_dataset', 'test', 'real', value)] = 0

final_dict['AnalogDiffusion'] = temp_dict

temp_dict={}
for value in os.listdir(os.path.join('FM_genimages', 'DreamlikePhotoreal')):
    temp_dict[os.path.join('FM_genimages', 'DreamlikePhotoreal', value)] = 1

for value in os.listdir(os.path.join('SD_dataset', 'test', 'real')):
    temp_dict[os.path.join('SD_dataset', 'test', 'real', value)] = 0

final_dict['DreamlikePhotoreal'] = temp_dict

temp_dict={}
for value in os.listdir(os.path.join('FM_genimages', 'DreamShaper')):
    temp_dict[os.path.join('FM_genimages', 'DreamShaper', value)] = 1

for value in os.listdir(os.path.join('SD_dataset', 'test', 'real')):
    temp_dict[os.path.join('SD_dataset', 'test', 'real', value)] = 0

final_dict['DreamShaper'] = temp_dict

temp_dict={}
for value in os.listdir(os.path.join('FM_genimages', 'EpicDiffusion')):
    temp_dict[os.path.join('FM_genimages', 'EpicDiffusion', value)] = 1

for value in os.listdir(os.path.join('SD_dataset', 'test', 'real')):
    temp_dict[os.path.join('SD_dataset', 'test', 'real', value)] = 0

final_dict['EpicDiffusion'] = temp_dict

temp_dict={}
for value in os.listdir(os.path.join('FM_genimages', 'epiCRealism')):
    temp_dict[os.path.join('FM_genimages', 'epiCRealism', value)] = 1

for value in os.listdir(os.path.join('SD_dataset', 'test', 'real')):
    temp_dict[os.path.join('SD_dataset', 'test', 'real', value)] = 0

final_dict['epiCRealism'] = temp_dict

temp_dict={}
for value in os.listdir(os.path.join('FM_genimages', 'FotoAssistedDiffusion')):
    temp_dict[os.path.join('FM_genimages', 'FotoAssistedDiffusion', value)] = 1

for value in os.listdir(os.path.join('SD_dataset', 'test', 'real')):
    temp_dict[os.path.join('SD_dataset', 'test', 'real', value)] = 0

final_dict['FotoAssistedDiffusion'] = temp_dict


temp_dict={}
for value in os.listdir(os.path.join('FM_genimages', 'Haveall')):
    temp_dict[os.path.join('FM_genimages', 'Haveall', value)] = 1

for value in os.listdir(os.path.join('SD_dataset', 'test', 'real')):
    temp_dict[os.path.join('SD_dataset', 'test', 'real', value)] = 0

final_dict['Haveall'] = temp_dict


with open('test.json', 'w') as json_file:
    json.dump(final_dict, json_file, indent=4)

# %% [markdown]
# # FakeCOCO

# %%
model_names = [
    "FLUX",
    "PixArt-XL-2-1024-MS",
    "stable-cascade",
    "stable-diffusion-3-medium",
    "stable-diffusion-xl-base-1.0",
    "PixArt-Sigma-XL-2-1024-MS",
    "playground-v2.5-1024px-aesthetic",
    "stable-diffusion-2-1",
    "stable-diffusion-v1-5",
    "sd-vae-ft-mse",
    "unidiffuser-v1"
]

import json
import os
import random

fake_set = set()
for path in os.listdir('FLUX'):
    fake_set.add(path.split('.')[0])

real_set = set()
for path in os.listdir('real'):
    real_set.add(path.split('.')[0])

vae_set = set()
for path in os.listdir('sd-vae-ft-mse'):
    vae_set.add(path.split('.')[0])

intersection_set = fake_set.intersection(real_set, vae_set)


sample_size = 3000
test_set = random.sample(intersection_set, sample_size)
train_set = list(intersection_set - set(test_set))

final_dict = {}
for model in model_names:
    temp_dict={}
    for value in train_set:
        temp_dict[os.path.join(model, value+'.png')] = 1
    for value in train_set:
        temp_dict[os.path.join('real', value+'.jpg')] = 0
    final_dict[model] = temp_dict

with open('train.json', 'w') as json_file:
    json.dump(final_dict, json_file, indent=4)


final_dict = {}
for model in model_names:
    temp_dict={}
    for value in test_set:
        temp_dict[os.path.join(model, value+'.png')] = 1
    for value in test_set:
        temp_dict[os.path.join('real', value+'.jpg')] = 0
    final_dict[model] = temp_dict

with open('test.json', 'w') as json_file:
    json.dump(final_dict, json_file, indent=4)

# %% [markdown]
# # FakePOP

# %%
model_names = [
    "FLUX",
    "PixArt-XL-2-1024-MS",
    "stable-cascade",
    "stable-diffusion-3-medium",
    "stable-diffusion-xl-base-1.0",
    "PixArt-Sigma-XL-2-1024-MS",
    "playground-v2.5-1024px-aesthetic",
    "stable-diffusion-2-1",
    "stable-diffusion-v1-5",
    "unidiffuser-v1"
]


import json
import os
import random

real_set = set()
for path in os.listdir('real'):
    real_set.add(path.split('.')[0])

fake_set = set()
for path in os.listdir('FLUX'):
    fake_set.add(path.split('.')[0].zfill(9))

other_set = set()
for path in os.listdir('PixArt-XL-2-1024-MS'):
    other_set.add(path.split('.')[0].zfill(9))


test_set = fake_set.intersection(real_set, other_set)
train_set= fake_set.intersection(real_set) - test_set

final_dict = {}
for model in ["stable-diffusion-v1-5"]:
    temp_dict={}
    for value in train_set:
        temp_dict[os.path.join(model, value.lstrip('0')+'.png')] = 1
    for value in train_set:
        temp_dict[os.path.join('real', value+'.jpg')] = 0
    final_dict[model] = temp_dict

with open('train.json', 'w') as json_file:
    json.dump(final_dict, json_file, indent=4)


final_dict = {}
for model in model_names:
    temp_dict={}
    for value in test_set:
        temp_dict[os.path.join(model, value.lstrip('0')+'.png')] = 1
    for value in test_set:
        temp_dict[os.path.join('real', value+'.jpg')] = 0
    final_dict[model] = temp_dict

with open('test.json', 'w') as json_file:
    json.dump(final_dict, json_file, indent=4)
